# %%
# Colab preprocessing for toronto_air_pollution_and_covid-19.csv
# Output: ready_for_viz.csv (saved back to Google Drive)

# 0) Mount Google Drive (Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Colab setup
# !pip -q install spacy nltk scikit-learn pandas numpy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 112.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# 1) Imports
import os
import re
import numpy as np
import pandas as pd

# 2) Paths — EDIT THESE AS NEEDED
DATA_DIR = "/content/drive/My Drive/Data Visualization"  # <-- change to your folder
INPUT_CSV = "Datathon2_drug_review.csv"  # <-- confirm the file name
OUTPUT_CSV = "ready_for_viz_2.csv"

in_path = os.path.join(DATA_DIR, INPUT_CSV)
out_path = os.path.join(DATA_DIR, OUTPUT_CSV)

# %%
import nltk
nltk.download('vader_lexicon')

import spacy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
nlp = spacy.load("en_core_web_sm")

# For reproducibility
RANDOM_STATE = 13
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = pd.read_csv(in_path)
# Basic cleanup
df = df.rename(columns=str.strip)
df = df.dropna(subset=['rating'])  # ensure rating exists
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
all_conditions = set(df['condition'].dropna().unique())
print(f"Total unique conditions: {len(all_conditions)}")
for cond in sorted(all_conditions):
    print(cond)

# %%
# 1) Keywords to flag mental-health conditions (edit/extend as needed)
mh_keywords = [
    # core diagnoses
    "depress", "anxiety", "bipolar", "schizo", "psychosis", "psychotic",
    "ptsd", "ocd", "adhd", "add", "autism", "asperger", "panic",
    "insomnia", "sleep", "manic", "mania", "mood", "pmdd", "pms",
    "borderline", "personality disorder", "eating", "anorexia", "bulimia",
    "substance", "alcohol", "opiate", "opioid", "addiction", "dependence",
    "withdrawal", "tourette", "tics",
    # symptoms/states often used as “condition” labels in reviews
    "agitation", "restless", "nervous", "fear", "phobia",
    "stress", "trauma"
]

# 2) Build the matched mental-health condition set (to review first)
def find_keyword(cond):
    for k in mh_keywords:
        if k in cond:
            return k   # first matching keyword
    return None

df['keyword'] = df['condition_clean'].apply(find_keyword)

# Keep only rows where a keyword matched
df_mh = df[df['keyword'].notna()].copy()

# %%
from spacy.lang.en.stop_words import STOP_WORDS

custom_stops = {
    # add domain-specific stops here
    "covid", "coronavirus"
}
STOP_WORDS |= custom_stops

def clean_text(text):
    if pd.isna(text):
        return ""
    # normalize
    t = text.lower()
    t = re.sub(r"(f|ht)tp\S+\s*", " ", t)              # URLs
    t = re.sub(r"@[A-Za-z0-9_]+", " ", t)              # at handles
    t = re.sub(r"#[A-Za-z0-9_]+", " ", t)              # hashtags
    t = re.sub(r"[^\x00-\x7F]+", " ", t)               # emojis/non-ascii
    t = re.sub(r"[^a-z\s]", " ", t)                    # keep letters/spaces
    t = re.sub(r"\s+", " ", t).strip()

    doc = nlp(t)
    toks = []
    for tok in doc:
        if tok.is_stop:
            continue
        lemma = tok.lemma_.strip()
        if len(lemma) >= 3:
            toks.append(lemma)
    return " ".join(toks)

for col in ['benefitsReview','sideEffectsReview','commentsReview']:
    if col in df_mh.columns:
        df_mh[f'{col}_clean'] = df_mh[col].apply(clean_text)

# %%
df_mh.to_csv(out_path, index=False)
print(f"Saved: {out_path} with {len(df_mh)} rows and {df_mh.shape[1]} columns.")
# Out:
# Saved: /content/drive/My Drive/Data Visualization/ready_for_viz_2.csv with 1092 rows and 12 columns.

# %%
df_mh
# Out:
#       Unnamed: 0  urlDrugName  rating           effectiveness  \
# 1           3724     lamictal       9        Highly Effective
# 2           3824     depakene       4    Moderately Effective
# 3            969      sarafem      10        Highly Effective
# 8           2576     klonopin      10        Highly Effective
# 9           1093      effexor       1    Marginally Effective
# ...          ...          ...     ...                     ...
# 4121         801       ambien       7    Moderately Effective
# 4130         539    trazodone      10        Highly Effective
# 4135        2613  adderall-xr       8  Considerably Effective
# 4138        1039      vyvanse      10        Highly Effective
# 4139        3281       zoloft       1             Ineffective
#
#                         sideEffects                condition  \
# 1                 Mild Side Effects         bipolar disorder
# 2               Severe Side Effects         bipolar disorder
# 3                   No Side Effects       bi-polar / anxiety
# 8                   No Side Effects           panic disorder
# 9     Extremely Severe Side Effects               depression
# ...                             ...                      ...
# 4121                No Side Effects                    sleep
# 4130                No Side Effects  chronic severe insomnia
# 4135          Moderate Side Effects                     adhd
# 4138              Mild Side Effects                     adhd
# 4139  Extremely Severe Side Effects               depression
#
#                                          benefitsReview  \
# 1     Lamictal stabilized my serious mood swings. On...
# 2     Initial benefits were comparable to the brand ...
# 3     It controlls my mood swings. It helps me think...
# 8     I immediately stopped having panic attacks.  I...
# 9     the presumed benefits were to help with a seve...
# ...                                                 ...
# 4121                               to get restful sleep
# 4130  This medication was the only thing that was ab...
# 4135  The medication helped the patient focus on dai...
# 4138  Increased focus, attention, productivity. Bett...
# 4139    Emotions were somewhat blunted. Less moodiness.
#
#                                       sideEffectsReview  \
# 1     Drowsiness, a bit of mental numbness. If you t...
# 2     Depakene has a very thin coating, which caused...
# 3               I didnt really notice any side effects.
# 8     I experienced no side effects.  I was not tire...
# 9     here we go.the initial effect would be dry mou...
# ...                                                 ...
# 4121                         sleepiness, drowiness, etc
# 4130                        There were no side effects.
# 4135  The patient experienced some side-effects, inc...
# 4138  Restless legs at night, insomnia, headache (so...
# 4139  Weight gain, extreme tiredness during the day,...
#
#                                          commentsReview  \
# 1     Severe mood swings between hypomania and depre...
# 2     Depakote was prescribed to me by a Kaiser psyc...
# 3     This drug may not be for everyone but its wond...
# 8     I started both klonopin and prozac together.  ...
# 9     family doctor initially prescribed wellbutin b...
# ...                                                 ...
# 4121  swallow the pill with water before bed. I was ...
# 4130  I usually took 150 mg. per night.  Occasionall...
# 4135  The patient was diagnosed with ADHD after desc...
# 4138  I took adderall once as a child, and it made m...
# 4139  I was on Zoloft for about 2 years total. I am ...
#
#                                    benefitsReview_clean  \
# 1     lamictal stabilize mood swing minute claw wall...
# 2     initial benefit comparable brand version drug ...
# 3     controll mood swing help think act speak contr...
# 8     immediately stop have panic attack miraculous ...
# 9     presume benefit help severe depression beginni...
# ...                                                 ...
# 4121                                      restful sleep
# 4130  medication thing able sleep regularly year chr...
# 4135  medication help patient focus daily activity t...
# 4138  increase focus attention productivity well abl...
# 4139                   emotion somewhat blunt moodiness
#
#                                 sideEffectsReview_clean  \
# 1     drowsiness bit mental numbness feel sedated ab...
# 2     depakene thin coating cause severe heart burn ...
# 3                                     not notice effect
# 8                experience effect tired feel medicated
# 9     initial effect dry mouth sleepiness able think...
# ...                                                 ...
# 4121                           sleepiness drowiness etc
# 4130                                             effect
# 4135  patient experience effect include dry mouth in...
# 4138  restless leg night insomnia headache pretty ba...
# 4139  weight gain extreme tiredness day insomnia nig...
#
#                                    commentsReview_clean
# 1     severe mood swing hypomania depression suicide...
# 2     depakote prescribe kaiser psychiatrist pleasan...
# 3     drug wonderful make totally different person w...
# 8     start klonopin prozac take klonopin time day g...
# 9     family doctor initially prescribe wellbutin ps...
# ...                                                 ...
# 4121  swallow pill water bed ambient wake middle nig...
# 4130  usually take night occasionally trouble fall a...
# 4135  patient diagnose adhd describe pattern focus m...
# 4138  take adderall child miserable want concerta ad...
# 4139  zoloft year total extremely sensitive medicati...
#
# [1092 rows x 12 columns]
